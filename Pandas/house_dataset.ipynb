# %%
import pandas as pd

# %%
dados = pd.read_csv('House/house.csv')

# %%
dados.loc[dados['Suburb'] == 'Roxburgh Park']
# Out:
#               Suburb            Address  Rooms Type     Price Method  \
# 540    Roxburgh Park       34 Boyden Sq      3    h       NaN     PN
# 541    Roxburgh Park         2 Dendy Ct      4    h  462000.0      S
# 542    Roxburgh Park         6 Korab Pl      4    h  448000.0      S
# 543    Roxburgh Park      15 Reading Cl      3    h  393500.0      S
# 544    Roxburgh Park       34 Spence Av      3    h       NaN     PI
# ...              ...                ...    ...  ...       ...    ...
# 62865  Roxburgh Park  10 Pickersgill Cr      4    h       NaN     SP
# 62866  Roxburgh Park      10 Tiffany Cr      4    h  630000.0     SP
# 63018  Roxburgh Park          3 Carr Pl      3    h  566000.0      S
# 63019  Roxburgh Park        9 Parker Ct      3    h  500000.0      S
# 63020  Roxburgh Park     5 Parkinson Wy      3    h  545000.0      S
#
#          SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
dados.sort_values('Rooms')
# Out:
#                Suburb                Address  Rooms Type      Price Method  \
# 20338  West Footscray      205/172 Rupert St      1    u        NaN     PI
# 46144        Carnegie         8/36 Moonya Rd      1    u   331000.0     SP
# 35869         Hampton     407/427 Hampton St      1    u   390000.0     VB
# 24558   Hawthorn East  121/138 Camberwell Rd      1    u        NaN      W
# 24550        Hawthorn             3/1 Elm St      1    u   480000.0     VB
# ...               ...                    ...    ...  ...        ...    ...
# 21337          Melton         213 Station Rd     12    h   710000.0      S
# 7952          Clayton      2015 Dandenong Rd     12    h        NaN     PI
# 58870         Preston       12 Lyonsville Av     12    h        NaN     SN
# 59741         Mitcham         20 Harrison St     16    h  5000000.0      S
# 55467  Wantirna South         5 Cottswold Pl     31    h   990000.0      S
#
# ...

# %%
dados.sort_values('CouncilArea', ascending = False)
# Out:
#                Suburb                 Address  Rooms Type     Price Method  \
# 31365  Chirnside Park        35 Bardaster Bvd      3    t       NaN     PN
# 13671     Mooroolbark            54 Barker Dr      4    h  712000.0     PI
# 20146  Chirnside Park          5 Buggyride La      4    h  680000.0     VB
# 31720     Mooroolbark            54 Barker Dr      4    h  712000.0     PI
# 59759     Mooroolbark            2 Darnley Wy      4    h       NaN     VB
# ...               ...                     ...    ...  ...       ...    ...
# 44420        Bundoora    104/11 Copernicus Cr      1    u  290000.0     VB
# 44421        Bundoora        18 Manchester Cr      3    t       NaN     PI
# 44422        Bundoora           12 Neilsen Cr      3    h  476000.0      S
# 44423        Bundoora       4/31 Sanctuary Dr      3    h       NaN     PI
# 31848         Rosanna  2/30 Mountain View Pde      3    u       NaN     VB
#
# ...

# %%
#dados.sort_values(['Suburb', 'Rooms'], ascending = False) não é muito bom
# Out:
#   Cell In[39], line 3
#     dados.sort_values(['Suburb', 'Rooms'])
#     ^
# IndentationError: unexpected indent

# %%
dados.sort_values(['Suburb', 'Rooms'])
# Out:
#            Suburb             Address  Rooms Type      Price Method  \
# 10592  Abbotsford   55/84 Trenerry Cr      1    u   570000.0     SP
# 15752  Abbotsford  6/241 Nicholson St      1    u   300000.0      S
# 18063  Abbotsford  504/12 Trenerry Cr      1    u   420000.0     VB
# 19148  Abbotsford   106/119 Turner St      1    u   481000.0     SP
# 22959  Abbotsford   13/84 Trenerry Cr      1    u   500000.0      S
# ...           ...                 ...    ...  ...        ...    ...
# 44360  Yarraville      173 Francis St      6    h        NaN     PI
# 61298  Yarraville     54 Pentland Pde      6    h  2450000.0     VB
# 8413   Yarraville         245 Hyde St      7    h  1260000.0      S
# 53636     croydon          81 hull Rd      3    h   730000.0      S
# 60080    viewbank        1/95 lyon Rd      3    t   885000.0     SP
#
#             SellerG        Date  Postcode             Regionname  \
# 10592        Biggin   7/04/2018      3067  Northern Metropolitan
# ...
