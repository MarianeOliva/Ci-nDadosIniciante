# %%
import pandas as pd
import re

# %%
df = pd.read_csv('CoffeQualityData/coffee_data.csv')

# %%
df.groupby(['Country of Origin']).mean(1).sort_values('Aroma', ascending=False).head(10)
# Out:
#                               Unnamed: 0          ID  Number of Bags  \
# Country of Origin
# Madagascar                     81.000000   81.000000        5.000000
# Tanzania, United Republic Of   64.833333   64.833333      330.000000
# Ethiopia                       54.000000   54.000000      240.181818
# Taiwan                         79.524590   79.524590        8.000000
# Kenya                         104.000000  104.000000      156.500000
# Uganda                         93.666667   93.666667      263.333333
# Myanmar                       107.000000  107.000000      100.000000
# Panama                        107.000000  107.000000      200.000000
# Colombia                      104.842105  104.842105      161.263158
# Laos                          114.000000  114.000000      129.333333
#
#                                  Aroma    Flavor  Aftertaste   Acidity  \
# Country of Origin
# Madagascar                    7.920000  7.920000    7.580000  7.750000
# ...

# %%
df.groupby(['Country of Origin']).sum(1).sort_values('Aroma', ascending=False).head(10)
# Out:
#                    Unnamed: 0    ID  Number of Bags   Aroma  Flavor  \
# Country of Origin
# Taiwan                   4851  4851             488  478.41  479.87
# Guatemala                1683  1683            6432  161.65  165.50
# Colombia                 1992  1992            3064  147.83  147.51
# Honduras                 1630  1630            2884  100.18   99.58
# Thailand                 1671  1671              33   89.60   91.59
# Ethiopia                  594   594            2642   86.51   86.58
# Brazil                   1538  1538            5669   74.75   74.92
# Costa Rica                861   861            1442   60.74   61.84
# Nicaragua                1125  1125            1594   52.33   51.99
# El Salvador              1164  1164            1498   51.33   51.66
#
#                    Aftertaste  Acidity    Body  Balance  Uniformity  \
# Country of Origin
# Taiwan                 470.44   473.68  467.34   471.59       608.0
# ...

# %%
df.groupby(['Country of Origin']).count().sort_values('Aroma', ascending=False).head(10)
# Out:
#                    Unnamed: 0  ID  Farm Name  Lot Number  Mill  ICO Number  \
# Country of Origin
# Taiwan                     61  61         61          61    61           5
# Guatemala                  21  21         21          21    19          16
# Colombia                   19  19         17          18    18           5
# Honduras                   13  13         13          13    13          10
# Thailand                   12  12         12          12    12           0
# Ethiopia                   11  11         11          11    11           9
# Brazil                     10  10         10          10    10           5
# Costa Rica                  8   8          8           8     8           4
# Nicaragua                   7   7          7           7     7           3
# El Salvador                 7   7          7           7     7           3
#
#                    Company  Altitude  Region  Producer  ...  Total Cup Points  \
# ...
