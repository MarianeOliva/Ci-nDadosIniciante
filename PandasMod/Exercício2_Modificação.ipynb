# %%
import pandas as pd
import re

# %%
df = pd.read_csv('Netflix_MO_SE/netflix_titles.csv')

# %%
modific = df.loc[df['country'] == 'United States', 'country'] = 'USA' 


print(modific)
# Out:
# The USA

# %%
modific2 = df.loc[df['country'] == 'USA', ['director', 'type']] = 'PYTHON', 'DATA SCIENCE'

df
# Out:
#      show_id          type                  title         director  \
# 0         s1  DATA SCIENCE   Dick Johnson Is Dead           PYTHON
# 1         s2       TV Show          Blood & Water              NaN
# 2         s3       TV Show              Ganglands  Julien Leclercq
# 3         s4       TV Show  Jailbirds New Orleans              NaN
# 4         s5       TV Show           Kota Factory              NaN
# ...      ...           ...                    ...              ...
# 8802   s8803  DATA SCIENCE                 Zodiac           PYTHON
# 8803   s8804       TV Show            Zombie Dumb              NaN
# 8804   s8805  DATA SCIENCE             Zombieland           PYTHON
# 8805   s8806  DATA SCIENCE                   Zoom           PYTHON
# 8806   s8807         Movie                 Zubaan      Mozez Singh
#
#                                                    cast       country  \
# 0                                                   NaN           USA
# ...

# %%
modific3 = df.loc[df['country'] == 'United Kingdom', ['country', 'director', 'type']] = 'UK', 'PYTHON', 'DATA SCIENCE'

df
# Out:
#      show_id          type                  title         director  \
# 0         s1  DATA SCIENCE   Dick Johnson Is Dead           PYTHON
# 1         s2       TV Show          Blood & Water              NaN
# 2         s3       TV Show              Ganglands  Julien Leclercq
# 3         s4       TV Show  Jailbirds New Orleans              NaN
# 4         s5       TV Show           Kota Factory              NaN
# ...      ...           ...                    ...              ...
# 8802   s8803  DATA SCIENCE                 Zodiac           PYTHON
# 8803   s8804       TV Show            Zombie Dumb              NaN
# 8804   s8805  DATA SCIENCE             Zombieland           PYTHON
# 8805   s8806  DATA SCIENCE                   Zoom           PYTHON
# 8806   s8807         Movie                 Zubaan      Mozez Singh
#
#                                                    cast       country  \
# 0                                                   NaN           USA
# ...

# %%
localiz = df.loc[(df['country'] == 'USA') | (df['country'] == 'UK')]

print(localiz)
# Out:
#      show_id          type                          title director  \
# 0         s1  DATA SCIENCE           Dick Johnson Is Dead   PYTHON
# 8         s9  DATA SCIENCE  The Great British Baking Show   PYTHON
# 9        s10  DATA SCIENCE                   The Starling   PYTHON
# 15       s16  DATA SCIENCE              Dear White People   PYTHON
# 27       s28  DATA SCIENCE                      Grown Ups   PYTHON
# ...      ...           ...                            ...      ...
# 8791   s8792  DATA SCIENCE                    Young Adult   PYTHON
# 8793   s8794  DATA SCIENCE           Yours, Mine and Ours   PYTHON
# 8802   s8803  DATA SCIENCE                         Zodiac   PYTHON
# 8804   s8805  DATA SCIENCE                     Zombieland   PYTHON
# 8805   s8806  DATA SCIENCE                           Zoom   PYTHON
#
#                                                    cast country  \
# 0                                                   NaN     USA
# ...

# %%
localiz.to_csv('NetPyDS.csv', index=False)
